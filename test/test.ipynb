# %%
# %load_ext autoreload
# %autoreload 2
import concreteBeam as conc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
b = conc.RectBeam(28,500,450,40,10,20)
ast = b.bending_steel_required(120)
# Out:
# The area of longitudinal bending steel required = 746.52mm2

# %%
b.print_bending_capacity_curve()

# %%
b.print_shear_capacity_curve(10,2)

# %%
    import math
math.atan(1/1) * 180 / math.pi
# Out:
# 45.0
