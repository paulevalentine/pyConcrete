# %%
# %load_ext autoreload
# %autoreload 2
import structuralConcrete as conc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
a = conc.Concrete(28)
# Out:
# Eq(f_cm, f_ck + 8)
# Eq(f_cm, 36.0)
# Eq(f_ctm, 0.3*f_ck**(2/3))
# Eq(f_ctm, 2.77)
# Eq(E_cm, 11026.1191398*f_cm**0.3)
# Eq(E_cm, 3.23e+4)

# %%
a.fctm
# Out:
# 2.77

# %%
v
# Out:
# 63.0
